# %%
def prime_check(p):
    if n<=1:
        return false
    for i in (2,p):
        if p%i==0:
            return false 

        return true
num=int(input("Enter the number:"))      
print(prime_chek(num))
